# %% [markdown]
# # Embedder Exploration
#
# This Notebook contains explorations into the usage of the siglip2 embedding model for embedding images into a latent space such that similar objects can be zero-shot classified togethered.

# %%
# 0) Make sure pip tooling is sane for this interpreter
# %pip install -U pip setuptools wheel

# 1) Uninstall the common offenders + your requested deps (ignore errors if some aren't installed)
# %pip uninstall -y numpy psutil ipykernel jupyter_client jupyter_core traitlets
# %pip uninstall -y transformers huggingface-hub tokenizers safetensors accelerate
# %pip uninstall -y torch torchvision
# %pip uninstall -y matplotlib scikit-learn pandas pillow
# %pip uninstall -y mediapipe opencv-python chromadb

# 2) Reinstall kernel-critical pieces + psutil (fixes the 'psutil_windows.heap_info' crash)
# %pip install --no-cache-dir --force-reinstall psutil ipykernel jupyter_client jupyter_core traitlets

# 3) Pin NumPy to 1.x to avoid "compiled with NumPy 1.x cannot run in NumPy 2.x" issues (mediapipe/opencv/etc.)
# %pip install --no-cache-dir --force-reinstall "numpy<2"

# 4) Pin huggingface-hub to <1.0 to avoid the transformers<->hub mismatch you hit
# %pip install --no-cache-dir --force-reinstall "huggingface-hub>=0.34.0,<1.0"

# 5) Install everything you wanted (plus a few common HF companions)
# %pip install --no-cache-dir --upgrade \
    transformers accelerate tokenizers safetensors \
    torch torchvision \
    matplotlib scikit-learn pandas pillow \
    mediapipe opencv-python chromadb
# Out:
# Requirement already satisfied: pip in c:\users\colin\appdata\local\programs\python\python312\lib\site-packages (25.3)
# Requirement already satisfied: setuptools in c:\users\colin\appdata\local\programs\python\python312\lib\site-packages (80.10.2)
# Requirement already satisfied: wheel in c:\users\colin\appdata\local\programs\python\python312\lib\site-packages (0.46.3)
# Requirement already satisfied: packaging>=24.0 in c:\users\colin\appdata\local\programs\python\python312\lib\site-packages (from wheel) (25.0)
# Note: you may need to restart the kernel to use updated packages.
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: psutil 7.2.1
# Uninstalling psutil-7.2.1:
#   Successfully uninstalled psutil-7.2.1
# Found existing installation: ipykernel 7.1.0
# Uninstalling ipykernel-7.1.0:
#   Successfully uninstalled ipykernel-7.1.0
# Found existing installation: jupyter_client 8.8.0
# Uninstalling jupyter_client-8.8.0:
#   Successfully uninstalled jupyter_client-8.8.0
# Found existing installation: jupyter_core 5.9.1
# Uninstalling jupyter_core-5.9.1:
#   Successfully uninstalled jupyter_core-5.9.1
# Found existing installation: traitlets 5.14.3
# Uninstalling traitlets-5.14.3:
#   Successfully uninstalled traitlets-5.14.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\colin\AppData\Local\Programs\Python\Python312\Lib\site-packages\~sutil'.
# You can safely remove it manually.
# Found existing installation: transformers 4.57.1
# Uninstalling transformers-4.57.1:
#   Successfully uninstalled transformers-4.57.1
# Found existing installation: huggingface-hub 0.36.0
# Uninstalling huggingface-hub-0.36.0:
#   Successfully uninstalled huggingface-hub-0.36.0
# Found existing installation: tokenizers 0.22.1
# Uninstalling tokenizers-0.22.1:
#   Successfully uninstalled tokenizers-0.22.1
# Found existing installation: safetensors 0.6.2
# Uninstalling safetensors-0.6.2:
#   Successfully uninstalled safetensors-0.6.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping accelerate as it is not installed.
# Found existing installation: torch 2.6.0
# Uninstalling torch-2.6.0:
#   Successfully uninstalled torch-2.6.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping torchvision as it is not installed.
# Found existing installation: matplotlib 3.10.7
# Uninstalling matplotlib-3.10.7:
#   Successfully uninstalled matplotlib-3.10.7
# Found existing installation: scikit-learn 1.3.2
# Uninstalling scikit-learn-1.3.2:
#   Successfully uninstalled scikit-learn-1.3.2
# Found existing installation: pandas 2.1.4
# Uninstalling pandas-2.1.4:
#   Successfully uninstalled pandas-2.1.4
# Found existing installation: pillow 11.3.0
# Uninstalling pillow-11.3.0:
#   Successfully uninstalled pillow-11.3.0
# Note: you may need to restart the kernel to use updated packages.
# Found existing installation: mediapipe 0.10.13Note: you may need to restart the kernel to use updated packages.
#
# Uninstalling mediapipe-0.10.13:
#   Successfully uninstalled mediapipe-0.10.13
# Found existing installation: opencv-python 4.12.0.88
# Uninstalling opencv-python-4.12.0.88:
#   Successfully uninstalled opencv-python-4.12.0.88
# Found existing installation: chromadb 0.5.0
# Uninstalling chromadb-0.5.0:
#   Successfully uninstalled chromadb-0.5.0
# Collecting psutil
#   Downloading psutil-7.2.1-cp37-abi3-win_amd64.whl.metadata (23 kB)
# Collecting ipykernel
#   Downloading ipykernel-7.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting jupyter_client
#   Downloading jupyter_client-8.8.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyter_core
#   Downloading jupyter_core-5.9.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting traitlets
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting comm>=0.1.1 (from ipykernel)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel)
#   Downloading debugpy-1.8.19-cp312-cp312-win_amd64.whl.metadata (1.5 kB)
# Collecting ipython>=7.23.1 (from ipykernel)
#   Downloading ipython-9.9.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel)
#   Downloading matplotlib_inline-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting nest-asyncio>=1.4 (from ipykernel)
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting packaging>=22 (from ipykernel)
#   Downloading packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pyzmq>=25 (from ipykernel)
#   Downloading pyzmq-27.1.0-cp312-abi3-win_amd64.whl.metadata (6.0 kB)
# Collecting tornado>=6.2 (from ipykernel)
#   Downloading tornado-6.5.4-cp39-abi3-win_amd64.whl.metadata (2.9 kB)
# Collecting python-dateutil>=2.8.2 (from jupyter_client)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting platformdirs>=2.5 (from jupyter_core)
#   Downloading platformdirs-4.5.1-py3-none-any.whl.metadata (12 kB)
# Collecting colorama>=0.4.4 (from ipython>=7.23.1->ipykernel)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting decorator>=4.3.2 (from ipython>=7.23.1->ipykernel)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers>=1.0.0 (from ipython>=7.23.1->ipykernel)
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.18.1 (from ipython>=7.23.1->ipykernel)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=7.23.1->ipykernel)
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.11.0 (from ipython>=7.23.1->ipykernel)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data>=0.6.0 (from ipython>=7.23.1->ipykernel)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel)
#   Downloading wcwidth-0.3.5-py3-none-any.whl.metadata (26 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.18.1->ipython>=7.23.1->ipykernel)
#   Downloading parso-0.8.5-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->jupyter_client)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting executing>=1.2.0 (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel)
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel)
#   Downloading asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pure-eval (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading psutil-7.2.1-cp37-abi3-win_amd64.whl (136 kB)
# Downloading ipykernel-7.1.0-py3-none-any.whl (117 kB)
# Downloading jupyter_client-8.8.0-py3-none-any.whl (107 kB)
# Downloading jupyter_core-5.9.1-py3-none-any.whl (29 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading debugpy-1.8.19-cp312-cp312-win_amd64.whl (5.3 MB)
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    ------- -------------------------------- 1.0/5.3 MB 6.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.4/5.3 MB 5.8 MB/s eta 0:00:01
#    ------------------------- -------------- 3.4/5.3 MB 5.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.7/5.3 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.3/5.3 MB 5.6 MB/s  0:00:00
# Downloading ipython-9.9.0-py3-none-any.whl (621 kB)
#    ---------------------------------------- 0.0/621.4 kB ? eta -:--:--
#    ---------------------------------------- 621.4/621.4 kB 5.7 MB/s  0:00:00
# Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------- ------------- 1.0/1.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 5.2 MB/s  0:00:00
# Downloading parso-0.8.5-py2.py3-none-any.whl (106 kB)
# Downloading matplotlib_inline-0.2.1-py3-none-any.whl (9.5 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading packaging-26.0-py3-none-any.whl (74 kB)
# Downloading platformdirs-4.5.1-py3-none-any.whl (18 kB)
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 6.2 MB/s  0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pyzmq-27.1.0-cp312-abi3-win_amd64.whl (619 kB)
#    ---------------------------------------- 0.0/619.5 kB ? eta -:--:--
#    ---------------------------------------- 619.5/619.5 kB 5.8 MB/s  0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.1-py3-none-any.whl (27 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading tornado-6.5.4-cp39-abi3-win_amd64.whl (446 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.3.5-py3-none-any.whl (86 kB)
# Installing collected packages: pure-eval, wcwidth, traitlets, tornado, six, pyzmq, pygments, psutil, platformdirs, parso, packaging, nest-asyncio, executing, decorator, debugpy, comm, colorama, asttokens, stack_data, python-dateutil, prompt_toolkit, matplotlib-inline, jupyter_core, jedi, ipython-pygments-lexers, jupyter_client, ipython, ipykernel
#
#   Attempting uninstall: pure-eval
#
#     Found existing installation: pure_eval 0.2.3
#
#     Uninstalling pure_eval-0.2.3:
#
#       Successfully uninstalled pure_eval-0.2.3
#
#    ----------------------------------------  0/28 [pure-eval]
#   Attempting uninstall: wcwidth
#    ----------------------------------------  0/28 [pure-eval]
#     Found existing installation: wcwidth 0.2.13
#    ----------------------------------------  0/28 [pure-eval]
#     Uninstalling wcwidth-0.2.13:
#    ----------------------------------------  0/28 [pure-eval]
#       Successfully uninstalled wcwidth-0.2.13
#    ----------------------------------------  0/28 [pure-eval]
#    - --------------------------------------  1/28 [wcwidth]
#    - --------------------------------------  1/28 [wcwidth]
#    - --------------------------------------  1/28 [wcwidth]
#    -- -------------------------------------  2/28 [traitlets]
#    -- -------------------------------------  2/28 [traitlets]
#    -- -------------------------------------  2/28 [traitlets]
#    -- -------------------------------------  2/28 [traitlets]
#   Attempting uninstall: tornado
#    -- -------------------------------------  2/28 [traitlets]
#    ---- -----------------------------------  3/28 [tornado]
#     Found existing installation: tornado 6.4.1
#    ---- -----------------------------------  3/28 [tornado]
#     Uninstalling tornado-6.4.1:
#    ---- -----------------------------------  3/28 [tornado]
#       Successfully uninstalled tornado-6.4.1
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#    ---- -----------------------------------  3/28 [tornado]
#   Attempting uninstall: six
#    ---- -----------------------------------  3/28 [tornado]
#     Found existing installation: six 1.17.0
#    ---- -----------------------------------  3/28 [tornado]
#     Uninstalling six-1.17.0:
#    ---- -----------------------------------  3/28 [tornado]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#    ----- ----------------------------------  4/28 [six]
#       Successfully uninstalled six-1.17.0
#    ----- ----------------------------------  4/28 [six]
#   Attempting uninstall: pyzmq
#    ----- ----------------------------------  4/28 [six]
#     Found existing installation: pyzmq 26.2.0
#    ----- ----------------------------------  4/28 [six]
#    ------- --------------------------------  5/28 [pyzmq]
#     Uninstalling pyzmq-26.2.0:
#    ------- --------------------------------  5/28 [pyzmq]
#       Successfully uninstalled pyzmq-26.2.0
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#    ------- --------------------------------  5/28 [pyzmq]
#   Attempting uninstall: pygments
#    ------- --------------------------------  5/28 [pyzmq]
#     Found existing installation: Pygments 2.19.2
#    ------- --------------------------------  5/28 [pyzmq]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#     Uninstalling Pygments-2.19.2:
#    -------- -------------------------------  6/28 [pygments]
#       Successfully uninstalled Pygments-2.19.2
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    -------- -------------------------------  6/28 [pygments]
#    ---------- -----------------------------  7/28 [psutil]
#    ---------- -----------------------------  7/28 [psutil]
#   Attempting uninstall: platformdirs
#    ---------- -----------------------------  7/28 [psutil]
#     Found existing installation: platformdirs 4.3.6
#    ---------- -----------------------------  7/28 [psutil]
#    ----------- ----------------------------  8/28 [platformdirs]
#     Uninstalling platformdirs-4.3.6:
#    ----------- ----------------------------  8/28 [platformdirs]
#       Successfully uninstalled platformdirs-4.3.6
#    ----------- ----------------------------  8/28 [platformdirs]
#    ----------- ----------------------------  8/28 [platformdirs]
#   Attempting uninstall: parso
#    ----------- ----------------------------  8/28 [platformdirs]
#     Found existing installation: parso 0.8.4
#    ----------- ----------------------------  8/28 [platformdirs]
#     Uninstalling parso-0.8.4:
#    ----------- ----------------------------  8/28 [platformdirs]
#       Successfully uninstalled parso-0.8.4
#    ----------- ----------------------------  8/28 [platformdirs]
#    ------------ ---------------------------  9/28 [parso]
#    ------------ ---------------------------  9/28 [parso]
#    ------------ ---------------------------  9/28 [parso]
#    ------------ ---------------------------  9/28 [parso]
#    ------------ ---------------------------  9/28 [parso]
#   Attempting uninstall: packaging
#    ------------ ---------------------------  9/28 [parso]
#     Found existing installation: packaging 25.0
#    ------------ ---------------------------  9/28 [parso]
#     Uninstalling packaging-25.0:
#    ------------ ---------------------------  9/28 [parso]
#       Successfully uninstalled packaging-25.0
#    ------------ ---------------------------  9/28 [parso]
#    -------------- ------------------------- 10/28 [packaging]
#    -------------- ------------------------- 10/28 [packaging]
#    -------------- ------------------------- 10/28 [packaging]
#   Attempting uninstall: nest-asyncio
#    -------------- ------------------------- 10/28 [packaging]
#     Found existing installation: nest-asyncio 1.6.0
#    -------------- ------------------------- 10/28 [packaging]
#     Uninstalling nest-asyncio-1.6.0:
#    -------------- ------------------------- 10/28 [packaging]
#    --------------- ------------------------ 11/28 [nest-asyncio]
#    --------------- ------------------------ 11/28 [nest-asyncio]
#       Successfully uninstalled nest-asyncio-1.6.0
#    --------------- ------------------------ 11/28 [nest-asyncio]
#   Attempting uninstall: executing
#    --------------- ------------------------ 11/28 [nest-asyncio]
#     Found existing installation: executing 2.1.0
#    --------------- ------------------------ 11/28 [nest-asyncio]
#     Uninstalling executing-2.1.0:
#    --------------- ------------------------ 11/28 [nest-asyncio]
#       Successfully uninstalled executing-2.1.0
#    --------------- ------------------------ 11/28 [nest-asyncio]
#    ----------------- ---------------------- 12/28 [executing]
#    ----------------- ---------------------- 12/28 [executing]
#   Attempting uninstall: decorator
#    ----------------- ---------------------- 12/28 [executing]
#     Found existing installation: decorator 5.2.1
#    ----------------- ---------------------- 12/28 [executing]
#     Uninstalling decorator-5.2.1:
#    ----------------- ---------------------- 12/28 [executing]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#    ------------------ --------------------- 13/28 [decorator]
#       Successfully uninstalled decorator-5.2.1
#    ------------------ --------------------- 13/28 [decorator]
#   Attempting uninstall: debugpy
#    ------------------ --------------------- 13/28 [decorator]
#     Found existing installation: debugpy 1.8.6
#    ------------------ --------------------- 13/28 [decorator]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#     Uninstalling debugpy-1.8.6:
#    -------------------- ------------------- 14/28 [debugpy]
#       Successfully uninstalled debugpy-1.8.6
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#    -------------------- ------------------- 14/28 [debugpy]
#   Attempting uninstall: comm
#    -------------------- ------------------- 14/28 [debugpy]
#     Found existing installation: comm 0.2.2
#    -------------------- ------------------- 14/28 [debugpy]
#    --------------------- ------------------ 15/28 [comm]
#     Uninstalling comm-0.2.2:
#    --------------------- ------------------ 15/28 [comm]
#       Successfully uninstalled comm-0.2.2
#    --------------------- ------------------ 15/28 [comm]
#   Attempting uninstall: colorama
#    --------------------- ------------------ 15/28 [comm]
#     Found existing installation: colorama 0.4.6
#    --------------------- ------------------ 15/28 [comm]
#     Uninstalling colorama-0.4.6:
#    --------------------- ------------------ 15/28 [comm]
#       Successfully uninstalled colorama-0.4.6
#    --------------------- ------------------ 15/28 [comm]
#    ---------------------- ----------------- 16/28 [colorama]
#    ---------------------- ----------------- 16/28 [colorama]
#    ---------------------- ----------------- 16/28 [colorama]
#   Attempting uninstall: asttokens
#    ---------------------- ----------------- 16/28 [colorama]
#     Found existing installation: asttokens 2.4.1
#    ---------------------- ----------------- 16/28 [colorama]
#     Uninstalling asttokens-2.4.1:
#    ---------------------- ----------------- 16/28 [colorama]
#       Successfully uninstalled asttokens-2.4.1
#    ---------------------- ----------------- 16/28 [colorama]
#    ------------------------ --------------- 17/28 [asttokens]
#    ------------------------ --------------- 17/28 [asttokens]
#   Attempting uninstall: stack_data
#    ------------------------ --------------- 17/28 [asttokens]
#     Found existing installation: stack-data 0.6.3
#    ------------------------ --------------- 17/28 [asttokens]
#     Uninstalling stack-data-0.6.3:
#    ------------------------ --------------- 17/28 [asttokens]
#       Successfully uninstalled stack-data-0.6.3
#    ------------------------ --------------- 17/28 [asttokens]
#    ------------------------- -------------- 18/28 [stack_data]
#   Attempting uninstall: python-dateutil
#    ------------------------- -------------- 18/28 [stack_data]
#     Found existing installation: python-dateutil 2.9.0.post0
#    ------------------------- -------------- 18/28 [stack_data]
#     Uninstalling python-dateutil-2.9.0.post0:
#    ------------------------- -------------- 18/28 [stack_data]
#       Successfully uninstalled python-dateutil-2.9.0.post0
#    ------------------------- -------------- 18/28 [stack_data]
#    --------------------------- ------------ 19/28 [python-dateutil]
#    --------------------------- ------------ 19/28 [python-dateutil]
#    --------------------------- ------------ 19/28 [python-dateutil]
#    --------------------------- ------------ 19/28 [python-dateutil]
#   Attempting uninstall: prompt_toolkit
#    --------------------------- ------------ 19/28 [python-dateutil]
#     Found existing installation: prompt_toolkit 3.0.48
#    --------------------------- ------------ 19/28 [python-dateutil]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#     Uninstalling prompt_toolkit-3.0.48:
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#       Successfully uninstalled prompt_toolkit-3.0.48
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#   Attempting uninstall: matplotlib-inline
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#     Found existing installation: matplotlib-inline 0.1.7
#    ---------------------------- ----------- 20/28 [prompt_toolkit]
#    ------------------------------ --------- 21/28 [matplotlib-inline]
#     Uninstalling matplotlib-inline-0.1.7:
#    ------------------------------ --------- 21/28 [matplotlib-inline]
#       Successfully uninstalled matplotlib-inline-0.1.7
#    ------------------------------ --------- 21/28 [matplotlib-inline]
#    ------------------------------- -------- 22/28 [jupyter_core]
#    ------------------------------- -------- 22/28 [jupyter_core]
#    ------------------------------- -------- 22/28 [jupyter_core]
#    ------------------------------- -------- 22/28 [jupyter_core]
#    ------------------------------- -------- 22/28 [jupyter_core]
#   Attempting uninstall: jedi
#    ------------------------------- -------- 22/28 [jupyter_core]
#     Found existing installation: jedi 0.19.1
#    ------------------------------- -------- 22/28 [jupyter_core]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#     Uninstalling jedi-0.19.1:
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#       Successfully uninstalled jedi-0.19.1
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    -------------------------------- ------- 23/28 [jedi]
#    ----------------------------------- ---- 25/28 [jupyter_client]
#    ----------------------------------- ---- 25/28 [jupyter_client]
#    ----------------------------------- ---- 25/28 [jupyter_client]
#    ----------------------------------- ---- 25/28 [jupyter_client]
#    ----------------------------------- ---- 25/28 [jupyter_client]
#    ----------------------------------- ---- 25/28 [jupyter_client]
#    ----------------------------------- ---- 25/28 [jupyter_client]
#    ----------------------------------- ---- 25/28 [jupyter_client]
#   Attempting uninstall: ipython
#    ----------------------------------- ---- 25/28 [jupyter_client]
#     Found existing installation: ipython 8.28.0
#    ----------------------------------- ---- 25/28 [jupyter_client]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#     Uninstalling ipython-8.28.0:
#    ------------------------------------- -- 26/28 [ipython]
#       Successfully uninstalled ipython-8.28.0
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    ------------------------------------- -- 26/28 [ipython]
#    -------------------------------------- - 27/28 [ipykernel]
#    -------------------------------------- - 27/28 [ipykernel]
#    -------------------------------------- - 27/28 [ipykernel]
#    -------------------------------------- - 27/28 [ipykernel]
#    -------------------------------------- - 27/28 [ipykernel]
#    ---------------------------------------- 28/28 [ipykernel]
#
# Successfully installed asttokens-3.0.1 colorama-0.4.6 comm-0.2.3 debugpy-1.8.19 decorator-5.2.1 executing-2.2.1 ipykernel-7.1.0 ipython-9.9.0 ipython-pygments-lexers-1.1.1 jedi-0.19.2 jupyter_client-8.8.0 jupyter_core-5.9.1 matplotlib-inline-0.2.1 nest-asyncio-1.6.0 packaging-26.0 parso-0.8.5 platformdirs-4.5.1 prompt_toolkit-3.0.52 psutil-7.2.1 pure-eval-0.2.3 pygments-2.19.2 python-dateutil-2.9.0.post0 pyzmq-27.1.0 six-1.17.0 stack_data-0.6.3 tornado-6.5.4 traitlets-5.14.3 wcwidth-0.3.5
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\colin\AppData\Roaming\Python\Python312\site-packages\~ornado'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\colin\AppData\Roaming\Python\Python312\site-packages\~mq'.
#   You can safely remove it manually.
#   WARNING: The script pygmentize.exe is installed in 'c:\Users\colin\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts debugpy-adapter.exe and debugpy.exe are installed in 'c:\Users\colin\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\colin\AppData\Roaming\Python\Python312\site-packages\~ebugpy'.
#   You can safely remove it manually.
#   WARNING: The scripts jupyter-migrate.exe, jupyter-troubleshoot.exe and jupyter.exe are installed in 'c:\Users\colin\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-kernel.exe, jupyter-kernelspec.exe and jupyter-run.exe are installed in 'c:\Users\colin\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts ipython.exe and ipython3.exe are installed in 'c:\Users\colin\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# geopandas 1.0.1 requires numpy>=1.22, which is not installed.
# geopandas 1.0.1 requires pandas>=1.4.0, which is not installed.
# keras 3.11.3 requires numpy, which is not installed.
# moviepy 2.2.1 requires numpy>=1.25.0, which is not installed.
# moviepy 2.2.1 requires pillow<12.0,>=9.2.0, which is not installed.
# onnxruntime 1.22.1 requires numpy>=1.21.6, which is not installed.
# pyogrio 0.10.0 requires numpy, which is not installed.
# pytesseract 0.3.10 requires Pillow>=8.0.0, which is not installed.
# scikit-image 0.25.2 requires numpy>=1.24, which is not installed.
# scikit-image 0.25.2 requires pillow>=10.1, which is not installed.
# statsmodels 0.14.4 requires numpy<3,>=1.22.3, which is not installed.
# statsmodels 0.14.4 requires pandas!=2.1.0,>=1.4, which is not installed.
# tensorboard 2.20.0 requires numpy>=1.12.0, which is not installed.
# tensorboard 2.20.0 requires pillow, which is not installed.
# langchain-core 0.2.43 requires packaging<25,>=23.2, but you have packaging 26.0 which is incompatible.
# langchain-nvidia-ai-endpoints 0.3.9 requires langchain-core<0.4,>=0.3.0, but you have langchain-core 0.2.43 which is incompatible.
# python-jose 3.4.0 requires pyasn1<0.5.0,>=0.4.1, but you have pyasn1 0.6.1 which is incompatible.
# Collecting numpy<2
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/15.5 MB 6.3 MB/s eta 0:00:03
#    ------ --------------------------------- 2.4/15.5 MB 6.1 MB/s eta 0:00:03
#    --------- ------------------------------ 3.7/15.5 MB 6.1 MB/s eta 0:00:02
#    ------------ --------------------------- 5.0/15.5 MB 5.9 MB/s eta 0:00:02
#    --------------- ------------------------ 6.0/15.5 MB 5.8 MB/s eta 0:00:02
#    ------------------ --------------------- 7.3/15.5 MB 5.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.7/15.5 MB 5.9 MB/s eta 0:00:02
#    ------------------------- -------------- 9.7/15.5 MB 6.0 MB/s eta 0:00:01
#    --------------------------- ------------ 10.7/15.5 MB 5.7 MB/s eta 0:00:01
#    ------------------------------- -------- 12.1/15.5 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.4/15.5 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 14.4/15.5 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 5.8 MB/s  0:00:02
# Installing collected packages: numpy
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\colin\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# deepface 0.0.93 requires opencv-python>=4.5.5.64, which is not installed.
# deepface 0.0.93 requires pandas>=0.23.4, which is not installed.
# deepface 0.0.93 requires Pillow>=5.2.0, which is not installed.
# deepface 0.0.93 requires tensorflow>=1.9.0, which is not installed.
# geopandas 1.0.1 requires pandas>=1.4.0, which is not installed.
# hmmlearn 0.3.3 requires scikit-learn!=0.22.0,>=0.16, which is not installed.
# imageio 2.37.0 requires pillow>=8.3.2, which is not installed.
# langchain-chroma 0.2.2 requires chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0, which is not installed.
# moviepy 2.2.1 requires pillow<12.0,>=9.2.0, which is not installed.
# retina-face 0.0.17 requires opencv-python>=3.4.4, which is not installed.
# retina-face 0.0.17 requires Pillow>=5.2.0, which is not installed.
# retina-face 0.0.17 requires tensorflow>=1.9.0, which is not installed.
# scikit-image 0.25.2 requires pillow>=10.1, which is not installed.
# statsmodels 0.14.4 requires pandas!=2.1.0,>=1.4, which is not installed.
# tensorboard 2.20.0 requires pillow, which is not installed.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm>=4.42.1 (from huggingface-hub<1.0,>=0.34.0)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting typing-extensions>=3.7.4.3 (from huggingface-hub<1.0,>=0.34.0)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting colorama (from tqdm>=4.42.1->huggingface-hub<1.0,>=0.34.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting charset_normalizer<4,>=2 (from requests->huggingface-hub<1.0,>=0.34.0)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests->huggingface-hub<1.0,>=0.34.0)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface-hub<1.0,>=0.34.0)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests->huggingface-hub<1.0,>=0.34.0)
#   Downloading certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 566.1/566.1 kB 6.5 MB/s  0:00:00
# Downloading fsspec-2026.1.0-py3-none-any.whl (201 kB)
# Downloading packaging-26.0-py3-none-any.whl (74 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading filelock-3.20.3-py3-none-any.whl (16 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl (107 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
# Installing collected packages: urllib3, typing-extensions, pyyaml, packaging, idna, fsspec, filelock, colorama, charset_normalizer, certifi, tqdm, requests, huggingface-hub
#
#   Attempting uninstall: urllib3
#
#     Found existing installation: urllib3 2.5.0
#
#     Uninstalling urllib3-2.5.0:
#
#       Successfully uninstalled urllib3-2.5.0
#
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#   Attempting uninstall: typing-extensions
#    ----------------------------------------  0/13 [urllib3]
#     Found existing installation: typing_extensions 4.13.2
#    ----------------------------------------  0/13 [urllib3]
#     Uninstalling typing_extensions-4.13.2:
#    ----------------------------------------  0/13 [urllib3]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.13.2
#    --- ------------------------------------  1/13 [typing-extensions]
#    --- ------------------------------------  1/13 [typing-extensions]
#   Attempting uninstall: pyyaml
#    --- ------------------------------------  1/13 [typing-extensions]
#     Found existing installation: PyYAML 6.0.2
#    --- ------------------------------------  1/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [pyyaml]
#     Uninstalling PyYAML-6.0.2:
#    ------ ---------------------------------  2/13 [pyyaml]
#       Successfully uninstalled PyYAML-6.0.2
#    ------ ---------------------------------  2/13 [pyyaml]
#    ------ ---------------------------------  2/13 [pyyaml]
#    ------ ---------------------------------  2/13 [pyyaml]
#    ------ ---------------------------------  2/13 [pyyaml]
#   Attempting uninstall: packaging
#    ------ ---------------------------------  2/13 [pyyaml]
#    --------- ------------------------------  3/13 [packaging]
#     Found existing installation: packaging 26.0
#    --------- ------------------------------  3/13 [packaging]
#     Uninstalling packaging-26.0:
#    --------- ------------------------------  3/13 [packaging]
#       Successfully uninstalled packaging-26.0
#    --------- ------------------------------  3/13 [packaging]
#    --------- ------------------------------  3/13 [packaging]
#    --------- ------------------------------  3/13 [packaging]
#    --------- ------------------------------  3/13 [packaging]
#   Attempting uninstall: idna
#    --------- ------------------------------  3/13 [packaging]
#     Found existing installation: idna 3.10
#    --------- ------------------------------  3/13 [packaging]
#     Uninstalling idna-3.10:
#    --------- ------------------------------  3/13 [packaging]
#       Successfully uninstalled idna-3.10
#    --------- ------------------------------  3/13 [packaging]
#    ------------ ---------------------------  4/13 [idna]
#    ------------ ---------------------------  4/13 [idna]
#   Attempting uninstall: fsspec
#    ------------ ---------------------------  4/13 [idna]
#     Found existing installation: fsspec 2025.3.2
#    ------------ ---------------------------  4/13 [idna]
#     Uninstalling fsspec-2025.3.2:
#    ------------ ---------------------------  4/13 [idna]
#       Successfully uninstalled fsspec-2025.3.2
#    ------------ ---------------------------  4/13 [idna]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#   Attempting uninstall: filelock
#    --------------- ------------------------  5/13 [fsspec]
#     Found existing installation: filelock 3.18.0
#    --------------- ------------------------  5/13 [fsspec]
#    ------------------ ---------------------  6/13 [filelock]
#     Uninstalling filelock-3.18.0:
#    ------------------ ---------------------  6/13 [filelock]
#       Successfully uninstalled filelock-3.18.0
#    ------------------ ---------------------  6/13 [filelock]
#    ------------------ ---------------------  6/13 [filelock]
#    ------------------ ---------------------  6/13 [filelock]
#   Attempting uninstall: colorama
#    ------------------ ---------------------  6/13 [filelock]
#     Found existing installation: colorama 0.4.6
#    ------------------ ---------------------  6/13 [filelock]
#     Uninstalling colorama-0.4.6:
#    ------------------ ---------------------  6/13 [filelock]
#       Successfully uninstalled colorama-0.4.6
#    ------------------ ---------------------  6/13 [filelock]
#    --------------------- ------------------  7/13 [colorama]
#   Attempting uninstall: charset_normalizer
#    --------------------- ------------------  7/13 [colorama]
#     Found existing installation: charset-normalizer 3.4.1
#    --------------------- ------------------  7/13 [colorama]
#    ------------------------ ---------------  8/13 [charset_normalizer]
#     Uninstalling charset-normalizer-3.4.1:
#    ------------------------ ---------------  8/13 [charset_normalizer]
#       Successfully uninstalled charset-normalizer-3.4.1
#    ------------------------ ---------------  8/13 [charset_normalizer]
#    ------------------------ ---------------  8/13 [charset_normalizer]
#    ------------------------ ---------------  8/13 [charset_normalizer]
#    ------------------------ ---------------  8/13 [charset_normalizer]
#    ------------------------ ---------------  8/13 [charset_normalizer]
#   Attempting uninstall: certifi
#    ------------------------ ---------------  8/13 [charset_normalizer]
#     Found existing installation: certifi 2025.8.3
#    ------------------------ ---------------  8/13 [charset_normalizer]
#     Uninstalling certifi-2025.8.3:
#    ------------------------ ---------------  8/13 [charset_normalizer]
#       Successfully uninstalled certifi-2025.8.3
#    ------------------------ ---------------  8/13 [charset_normalizer]
#    --------------------------- ------------  9/13 [certifi]
#   Attempting uninstall: tqdm
#    --------------------------- ------------  9/13 [certifi]
#     Found existing installation: tqdm 4.67.1
#    --------------------------- ------------  9/13 [certifi]
#     Uninstalling tqdm-4.67.1:
#    --------------------------- ------------  9/13 [certifi]
#    ------------------------------ --------- 10/13 [tqdm]
#       Successfully uninstalled tqdm-4.67.1
#    ------------------------------ --------- 10/13 [tqdm]
#    ------------------------------ --------- 10/13 [tqdm]
#    ------------------------------ --------- 10/13 [tqdm]
#    ------------------------------ --------- 10/13 [tqdm]
#    ------------------------------ --------- 10/13 [tqdm]
#    ------------------------------ --------- 10/13 [tqdm]
#    ------------------------------ --------- 10/13 [tqdm]
#    ------------------------------ --------- 10/13 [tqdm]
#   Attempting uninstall: requests
#    ------------------------------ --------- 10/13 [tqdm]
#     Found existing installation: requests 2.32.5
#    ------------------------------ --------- 10/13 [tqdm]
#     Uninstalling requests-2.32.5:
#    ------------------------------ --------- 10/13 [tqdm]
#       Successfully uninstalled requests-2.32.5
#    ------------------------------ --------- 10/13 [tqdm]
#    --------------------------------- ------ 11/13 [requests]
#    --------------------------------- ------ 11/13 [requests]
#    --------------------------------- ------ 11/13 [requests]
#    --------------------------------- ------ 11/13 [requests]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ------------------------------------ --- 12/13 [huggingface-hub]
#    ---------------------------------------- 13/13 [huggingface-hub]
#
# Successfully installed certifi-2026.1.4 charset_normalizer-3.4.4 colorama-0.4.6 filelock-3.20.3 fsspec-2026.1.0 huggingface-hub-0.36.0 idna-3.11 packaging-26.0 pyyaml-6.0.3 requests-2.32.5 tqdm-4.67.1 typing-extensions-4.15.0 urllib3-2.6.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\colin\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\colin\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts hf.exe, huggingface-cli.exe and tiny-agents.exe are installed in 'c:\Users\colin\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anthropic 0.7.7 requires tokenizers>=0.13.0, which is not installed.
# deepface 0.0.93 requires opencv-python>=4.5.5.64, which is not installed.
# deepface 0.0.93 requires pandas>=0.23.4, which is not installed.
# deepface 0.0.93 requires Pillow>=5.2.0, which is not installed.
# deepface 0.0.93 requires tensorflow>=1.9.0, which is not installed.
# geopandas 1.0.1 requires pandas>=1.4.0, which is not installed.
# pytesseract 0.3.10 requires Pillow>=8.0.0, which is not installed.
# retina-face 0.0.17 requires opencv-python>=3.4.4, which is not installed.
# retina-face 0.0.17 requires Pillow>=5.2.0, which is not installed.
# retina-face 0.0.17 requires tensorflow>=1.9.0, which is not installed.
# scikit-image 0.25.2 requires pillow>=10.1, which is not installed.
# statsmodels 0.14.4 requires pandas!=2.1.0,>=1.4, which is not installed.
# tensorboard 2.20.0 requires pillow, which is not installed.
# google-genai 1.21.1 requires anyio<5.0.0,>=4.8.0, but you have anyio 3.7.1 which is incompatible.
# google-genai 1.21.1 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.25.2 which is incompatible.
# langchain-core 0.2.43 requires packaging<25,>=23.2, but you have packaging 26.0 which is incompatible.
# langchain-nvidia-ai-endpoints 0.3.9 requires langchain-core<0.4,>=0.3.0, but you have langchain-core 0.2.43 which is incompatible.
# pydantic-settings 2.10.0 requires pydantic>=2.7.0, but you have pydantic 2.5.0 which is incompatible.

# %%
# Install Dependencies
# %pip install transformers torch torchvision accelerate matplotlib scikit-learn numpy pandas mediapipe opencv-python chromadb pillow

# %%
# %pip uninstall -y numpy

# install a stable NumPy 1.x (commonly recommended)
# %pip install "numpy==1.26.4"

# reinstall the likely compiled packages so they match the NumPy you now have
# %pip install --force-reinstall --no-cache-dir mediapipe opencv-python scikit-learn matplotlib chromadb

# %%
# %pip install -U transformers huggingface-hub accelerate tokenizers safetensors --upgrade-strategy eager

# %% [markdown]
# ## Constants

# %%
# MODEL = "google/siglip2-so400m-patch14-384"
# MODEL = "facebook/dinov2-base"
MODEL = "openai/clip-vit-base-patch32"

# %% [markdown]
# ## Embedding a Single Image

# %%
import torch
from transformers import AutoModel, AutoProcessor
from transformers.image_utils import load_image
import time

model = AutoModel.from_pretrained(MODEL, device_map="auto").eval()
processor = AutoProcessor.from_pretrained(MODEL)

start = time.time()
image = load_image("./images/rubiks-cube.jpg")
print(f"Image Load Time: {time.time() - start}")

start = time.time()
inputs = processor(images=[image], return_tensors="pt").to(model.device)
print(f"Preprocessor Time: {time.time() - start}")

start = time.time()
with torch.no_grad():
    image_embeddings = model.get_image_features(**inputs)
print(f"Interence Elapsed Time: {time.time() - start}")

print(image_embeddings.shape)
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File c:\Users\colin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\image_utils.py:480, in load_image(image, timeout)
#     479 try:
# --> 480     b64 = base64.decodebytes(image.encode())
#     481     image = PIL.Image.open(BytesIO(b64))
#
# File c:\Users\colin\AppData\Local\Programs\Python\Python312\Lib\base64.py:554, in decodebytes(s)
#     553 _input_type_check(s)
# --> 554 return binascii.a2b_base64(s)
#
# Error: Invalid base64-encoded string: number of data characters (21) cannot be 1 more than a multiple of 4
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 10
#       7 processor = AutoProcessor.from_pretrained(MODEL)
#       9 start = time.time()
# ---> 10 image = load_image("./images/rubiks-cube.jpg")
#      11 print(f"Image Load Time: {time.time() - start}")
#      13 start = time.time()
#
# File c:\Users\colin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\image_utils.py:483, in load_image(image, timeout)
#     481             image = PIL.Image.open(BytesIO(b64))
#     482         except Exception as e:
# --> 483             raise ValueError(
#     484                 f"Incorrect image source. Must be a valid URL starting with `http://` or `https://`, a valid path to an image file, or a base64 encoded string. Got {image}. Failed with {e}"
#     485             )
#     486 elif not isinstance(image, PIL.Image.Image):
#     487     raise TypeError(
#     488         "Incorrect format used for image. Should be an url linking to an image, a base64 string, a local path, or a PIL image."
#     489     )
#
# ValueError: Incorrect image source. Must be a valid URL starting with `http://` or `https://`, a valid path to an image file, or a base64 encoded string. Got ./images/rubiks-cube.jpg. Failed with Invalid base64-encoded string: number of data characters (21) cannot be 1 more than a multiple of 4

# %% [markdown]
# ## Batch Embedding

# %%
import torch
from transformers import AutoModel, AutoProcessor
from transformers.image_utils import load_image
import matplotlib.pyplot as plt
import time

model = AutoModel.from_pretrained(MODEL, device_map="auto").eval()
processor = AutoProcessor.from_pretrained(MODEL)

x_axis = [1, 5, 10, 20, 50]
load_times = []
preprocessing_times = []
embedding_times = []

for value in x_axis:
    print(f"Working with {value} images")
    images = []
    start = time.time()
    for _ in range(value):
        images.append(load_image("./images/rubiks-cube.jpg"))
    load_times.append(time.time() - start)

    start = time.time()
    inputs = processor(images=images, return_tensors="pt").to(model.device)
    preprocessing_times.append(time.time() - start)

    start = time.time()
    with torch.no_grad():
        image_embeddings = model.get_image_features(**inputs)
    embedding_times.append(time.time() - start)

plt.subplot(221)
plt.plot(x_axis, load_times)
plt.title("Load Time (s) vs Number of Images")
plt.grid(True)

plt.subplot(222)
plt.plot(x_axis, preprocessing_times)
plt.title("Preprocessing Time (s) vs Number of Images")
plt.grid(True)

plt.subplot(223)
plt.plot(x_axis, embedding_times)
plt.title("Embedding Times (s) vs Number of Images")
plt.grid(True)

print(f"Number of Images: {x_axis}")
print(f"Load Times: {load_times}")
print(f"Preprocessing Times: {preprocessing_times}")
print(f"Embedding Times: {embedding_times}")
# Out:
# Working with 1 images
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File c:\Users\colin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\image_utils.py:480, in load_image(image, timeout)
#     479 try:
# --> 480     b64 = base64.decodebytes(image.encode())
#     481     image = PIL.Image.open(BytesIO(b64))
#
# File c:\Users\colin\AppData\Local\Programs\Python\Python312\Lib\base64.py:554, in decodebytes(s)
#     553 _input_type_check(s)
# --> 554 return binascii.a2b_base64(s)
#
# Error: Invalid base64-encoded string: number of data characters (21) cannot be 1 more than a multiple of 4
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 20
#      18 start = time.time()
#      19 for _ in range(value):
# ---> 20     images.append(load_image("./images/rubiks-cube.jpg"))
#      21 load_times.append(time.time() - start)
#      23 start = time.time()
#
# File c:\Users\colin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\image_utils.py:483, in load_image(image, timeout)
#     481             image = PIL.Image.open(BytesIO(b64))
#     482         except Exception as e:
# --> 483             raise ValueError(
#     484                 f"Incorrect image source. Must be a valid URL starting with `http://` or `https://`, a valid path to an image file, or a base64 encoded string. Got {image}. Failed with {e}"
#     485             )
#     486 elif not isinstance(image, PIL.Image.Image):
#     487     raise TypeError(
#     488         "Incorrect format used for image. Should be an url linking to an image, a base64 string, a local path, or a PIL image."
#     489     )
#
# ValueError: Incorrect image source. Must be a valid URL starting with `http://` or `https://`, a valid path to an image file, or a base64 encoded string. Got ./images/rubiks-cube.jpg. Failed with Invalid base64-encoded string: number of data characters (21) cannot be 1 more than a multiple of 4

# %% [markdown]
# # Embedding Pick Items Without Hand Clipping / Masking

# %%
import torch
from transformers import AutoModel, AutoProcessor
from transformers.image_utils import load_image
import os
import numpy as np

model = AutoModel.from_pretrained(MODEL, device_map="auto").eval()
processor = AutoProcessor.from_pretrained(MODEL)

images = [load_image(f"../../images/pick-items/{image}") for image in os.listdir("../../images/pick-items")]

inputs = processor(images=images, return_tensors="pt").to(model.device)

with torch.no_grad():
    embeddings = model.get_image_features(**inputs)

embeddings = embeddings.numpy()

shortest_distances = []
for i in range(len(images)):
    shortest_distance = 1e99
    for j in range(len(images)):
        if i == j:
            continue
        dist = np.linalg.norm(embeddings[j] - embeddings[i])
        if dist < shortest_distance:
            shortest_distance = dist
    shortest_distances.append(shortest_distance)

print(f"Shortest Distances: {shortest_distances}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 10
#       7 model = AutoModel.from_pretrained(MODEL, device_map="auto").eval()
#       8 processor = AutoProcessor.from_pretrained(MODEL)
# ---> 10 images = [load_image(f"../../images/pick-items/{image}") for image in os.listdir("../../images/pick-items")]
#      12 inputs = processor(images=images, return_tensors="pt").to(model.device)
#      14 with torch.no_grad():
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../../images/pick-items'

# %% [markdown]
# ## Embedding Pick Items with Hand Clipping

# %%
import numpy as np

def hand_pos(landmarks, image):
    if len(landmarks) < 21:
        # need at least 21 for a hand
        return ()

    # center of palm appears to be a better indicator for the location of the hand (more mass concentrated at that point)
    fingers = [[np.array(landmarks[i]) for i in range(j * 4 + 1, j * 4 + 5)] for j in range(5)]
    # base of the palm
    total_x = landmarks[0][0] * image.shape[1]
    total_y = landmarks[0][1] * image.shape[0]
    for finger in fingers:
        # look at base of the finger
        curr = finger[0]
        total_x += (curr[0] * image.shape[1])
        total_y += (curr[1] * image.shape[0])
    return (total_x / 6, total_y / 6)

def hand_bounding_box(landmarks, image):
    left = image.shape[1]
    right = -1
    top = image.shape[0]
    bottom = -1
    for (x, y, _) in landmarks:
        #adjust for pixel values
        x = x * image.shape[1]
        y = y * image.shape[0]
        if x < left:
            # point further left than current left
            left = x
        if x > right:
            # point further right than current right
            right = x
        if y < top:
            #point that is higher than top
            top = y
        if y > bottom:
            bottom = y

    #add a little buffer for the rest of the finger (the landmarks aren't exactly at the tip)
    top, bottom, left, right = int(top - 20), int(bottom + 20), int(left - 20), int(right + 20)
    # return points (top left and clockwise from there, (x, y) for points), size (height, width)
    return ((left, top), (right, top), (right, bottom), (left, bottom)), (bottom - top, right - left)

# %%
import mediapipe as mp
from matplotlib import pyplot as plt
import cv2
import copy

def draw_hand(image):
    mp_drawing = mp.solutions.drawing_utils
    mp_hands = mp.solutions.hands
    hands = mp_hands.Hands(min_detection_confidence=0.7, min_tracking_confidence=0.3, max_num_hands=2)
    results = hands.process(image)
    draw_image = copy.deepcopy(image)

    hand_points = []
    if results.multi_hand_landmarks:
        for (i, hand_landmarks) in enumerate(results.multi_hand_landmarks):
            mp_drawing.draw_landmarks(draw_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            points = []
            for i in hand_landmarks.landmark[:21]:
                points.append([i.x, i.y, i.z])
            hand_points.append(points)

    hand_positions = [hand_pos(hand_point, image) for hand_point in hand_points]
    left_hand_points = None
    left_hand_position = (1e99, 1e99)
    for (i, hand_position) in enumerate(hand_positions):
        if hand_position[0] < left_hand_position[0]:
            left_hand_position = hand_position
            left_hand_points = hand_points[i]

    bounding_box, bounding_box_size = hand_bounding_box(left_hand_points, image)
    for point_index in range(len(bounding_box)):
        cv2.line(draw_image, bounding_box[point_index], bounding_box[(point_index + 1) % len(bounding_box)], (0, 0, 255), 4)

    plt.imshow(draw_image)
    plt.show()

    plt.imshow(image[bounding_box[0][1]:bounding_box[2][1], bounding_box[0][0]:bounding_box[2][0]])
    plt.show()

    return image[bounding_box[0][1]:bounding_box[2][1], bounding_box[0][0]:bounding_box[2][0]]

# %%
import cv2
from matplotlib import pyplot as plt

image = cv2.imread("../../images/pick-items/alligatorclip.JPG")
image = cv2.resize(image, (1920, 1080))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()
hand = draw_hand(image)

# %%
import mediapipe as mp

def segment_hand(image):
    mp_hands = mp.solutions.hands
    hands = mp_hands.Hands(min_detection_confidence=0.7, min_tracking_confidence=0.3, max_num_hands=2)
    results = hands.process(image)

    hand_points = []
    if results.multi_hand_landmarks:
        for (i, hand_landmarks) in enumerate(results.multi_hand_landmarks):
            points = []
            for i in hand_landmarks.landmark[:21]:
                points.append([i.x, i.y, i.z])
            hand_points.append(points)
    else:
        return None

    if len(hand_points) > 1:
        hand_positions = [hand_pos(hand_point, image) for hand_point in hand_points]
        right_hand_points = None
        right_hand_position = (1e99, 1e99)
        for (i, hand_position) in enumerate(hand_positions):
            if hand_position[0] < right_hand_position[0]:
                right_hand_position = hand_position
                right_hand_points = hand_points[i]
    else:
        right_hand_points = hand_points[0]

    bounding_box, _ = hand_bounding_box(right_hand_points, image)

    return image[bounding_box[0][1]:bounding_box[2][1], bounding_box[0][0]:bounding_box[2][0]]

# %%
import numpy as np

def cosine_similarity(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
import torch
from transformers import AutoModel, AutoProcessor
from transformers.image_utils import load_image
import os
import numpy as np
from matplotlib import pyplot as plt
import cv2

model = AutoModel.from_pretrained(MODEL, device_map="auto").eval()
processor = AutoProcessor.from_pretrained(MODEL)

# images = [load_image(f"../../images/pick_items/{image}") for image in os.listdir("../../images/pick-items")]

# Form a box around the hand
images = []
for f in os.listdir("../../images/pick-items"):
    image = cv2.imread(f"../../images/pick-items/{f}")
    image = cv2.resize(image, (1920, 1080))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = segment_hand(image)
    images.append(image)

# Show the images
for image in images:
    plt.imshow(image)
    plt.show()

inputs = processor(images=images, return_tensors="pt").to(model.device)

with torch.no_grad():
    # outputs = model(**inputs)
    # embeddings = outputs.last_hidden_state.mean(dim=1)
    embeddings = model.get_image_features(**inputs)

# embeddings = torch.nn.functional.normalize(embeddings, p=2, dim=1)
embeddings = embeddings.numpy()

shortest_distances = []
for i in range(len(images)):
    shortest_distance = [1e99, -1]
    for j in range(len(images)):
        if i == j:
            continue
        dist = cosine_similarity(embeddings[j], embeddings[i])
        if dist < shortest_distance[0]:
            shortest_distance = [dist, i]
    shortest_distances.append(shortest_distance)

print(f"Shortest Distances: {shortest_distances}")

farthest_distances = []
for i in range(len(images)):
    farthest_distance = [-1e99, -1]
    for j in range(len(images)):
        if i == j:
            continue
        dist = cosine_similarity(embeddings[j], embeddings[i])
        if dist > farthest_distance[0]:
            farthest_distance = [dist, i]
    farthest_distances.append(farthest_distance)

print(f"Farthest Distances: {farthest_distances}")

# %% [markdown]
# # Different Backgrounds

# %%
import torch
from transformers import AutoModel, AutoProcessor
import os
import numpy as np
from matplotlib import pyplot as plt
import cv2

model = AutoModel.from_pretrained(MODEL, device_map="auto").eval()
processor = AutoProcessor.from_pretrained(MODEL)

images = []
for f in os.listdir("../../images/background-test"):
    image = cv2.imread(f"../../images/background-test/{f}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = segment_hand(image)
    image = cv2.resize(image, (1200, 1200))
    images.append(image)

# Show the images
for image in images:
    plt.imshow(image)
    plt.show()

inputs = processor(images=images, return_tensors="pt").to(model.device)

with torch.no_grad():
    # outputs = model(**inputs)
    # embeddings = outputs.last_hidden_state.mean(dim=1)
    embeddings = model.get_image_features(**inputs)

# embeddings = torch.nn.functional.normalize(embeddings, p=2, dim=1)
embeddings = embeddings.numpy()

shortest_distances = []
for i in range(len(images)):
    shortest_distance = [1e99, -1]
    for j in range(len(images)):
        if i == j:
            continue
        dist = cosine_similarity(embeddings[j], embeddings[i])
        if dist < shortest_distance[0]:
            shortest_distance = [dist, i]
    shortest_distances.append(shortest_distance)

print(f"Shortest Distances: {shortest_distances}")

farthest_distances = []
for i in range(len(images)):
    farthest_distance = [-1e99, -1]
    for j in range(len(images)):
        if i == j:
            continue
        dist = cosine_similarity(embeddings[j], embeddings[i])
        if dist > farthest_distance[0]:
            farthest_distance = [dist, i]
    farthest_distances.append(farthest_distance)

print(f"Farthest Distances: {farthest_distances}")

# %%
import torch
from transformers import AutoModel, AutoProcessor
import os
import numpy as np
from matplotlib import pyplot as plt
import cv2

model = AutoModel.from_pretrained(MODEL, device_map="auto").eval()
processor = AutoProcessor.from_pretrained(MODEL)

images = []
for f in os.listdir("../../images/orientation-test"):
    image = cv2.imread(f"../../images/orientation-test/{f}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = segment_hand(image)
    image = cv2.resize(image, (1200, 1200))
    images.append(image)

# Show the images
for image in images:
    plt.imshow(image)
    plt.show()

inputs = processor(images=images, return_tensors="pt").to(model.device)

with torch.no_grad():
    # outputs = model(**inputs)
    # embeddings = outputs.last_hidden_state.mean(dim=1)
    embeddings = model.get_image_features(**inputs)

# embeddings = torch.nn.functional.normalize(embeddings, p=2, dim=1)
embeddings = embeddings.numpy()

shortest_distances = []
for i in range(len(images)):
    shortest_distance = [1e99, -1]
    for j in range(len(images)):
        if i == j:
            continue
        dist = cosine_similarity(embeddings[j], embeddings[i])
        if dist < shortest_distance[0]:
            shortest_distance = [dist, i]
    shortest_distances.append(shortest_distance)

print(f"Shortest Distances: {shortest_distances}")

farthest_distances = []
for i in range(len(images)):
    farthest_distance = [-1e99, -1]
    for j in range(len(images)):
        if i == j:
            continue
        dist = cosine_similarity(embeddings[j], embeddings[i])
        if dist > farthest_distance[0]:
            farthest_distance = [dist, i]
    farthest_distances.append(farthest_distance)

print(f"Farthest Distances: {farthest_distances}")

# %% [markdown]
# # Embedding Picklists

# %%
import torch
from transformers import AutoModel, AutoProcessor
import os
import numpy as np
import cv2
import chromadb

model = AutoModel.from_pretrained(MODEL, device_map="auto").eval()
processor = AutoProcessor.from_pretrained(MODEL)
chroma_client = chromadb.Client()

chroma_client.delete_collection(name="embedding_picklist_test")
collection = chroma_client.create_collection(
    name="embedding_picklist_test",
    configuration={
        "hnsw": {
            "space": "cosine"
        }
    },
    metadata={
        "description": "test database for testing my model's ability to map images to names"
    }
)
id = 1

# %%
def embed(image, picklist, id: int, model, processor, collection):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = segment_hand(image)
    if image is None:
        print("Unable to Segment Image")
        return
    inputs = processor(images=[image], return_tensors="pt").to(model.device)
    with torch.no_grad():
        embeddings = model.get_image_features(**inputs)
    collection.add(
        ids=[f"id{id}"],
        embeddings=embeddings.numpy(),
        metadatas=[{"picklist": picklist}]
    )
    return embeddings.numpy()

# %%
picklists = ["gbr", "b", "br"]

# Embed picklists
for (i, picklist) in enumerate(picklists):
    for f in os.listdir(f"../../images/picklist-test/{i}"):
        image = cv2.imread(f"../../images/picklist-test/{i}/{f}")
        embed(image, picklist, id)
        id += 1

# %%
image = cv2.imread("../../images/picklist-test/test/b.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = segment_hand(image)
query = None
if image is not None:
    inputs = processor(images=[image], return_tensors="pt").to(model.device)
    with torch.no_grad():
        embeddings = model.get_image_features(**inputs)
    query = collection.query(
        query_embeddings=embeddings.numpy(),
    )
else:
    print("Could not find hands")
print(query)

# %%
image = cv2.imread("../../images/picklist-test/test/r.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = segment_hand(image)
query = None
if image is not None:
    inputs = processor(images=[image], return_tensors="pt").to(model.device)
    with torch.no_grad():
        embeddings = model.get_image_features(**inputs)
    query = collection.query(
        query_embeddings=embeddings.numpy(),
    )
else:
    print("Could not find hands")
print(query)

# %%
image = cv2.imread("../../images/picklist-test/test/g.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = segment_hand(image)
query = None
if image is not None:
    inputs = processor(images=[image], return_tensors="pt").to(model.device)
    with torch.no_grad():
        embeddings = model.get_image_features(**inputs)
    query = collection.query(
        query_embeddings=embeddings.numpy(),
    )
else:
    print("Could not find hands")
print(query)

# %% [markdown]
# # Creating heatmaps for our objects

# %%
from transformers import AutoModel, AutoProcessor
import chromadb

model = AutoModel.from_pretrained(MODEL, device_map="auto").eval()
processor = AutoProcessor.from_pretrained(MODEL)
chroma_client = chromadb.Client()

try:
    chroma_client.delete_collection(name="all_embeddings")
except:
    pass
collection = chroma_client.create_collection(
    name="all_embeddings",
    configuration={
        "hnsw": {
            "space": "cosine"
        }
    },
    metadata={
        "description": "test dataset for embedding all of the items we have"
    }
)
id = 1

# %%
import torch
import os
import cv2

def embed_and_process_img(image_name, id: int, model, processor, collection):
    image = cv2.imread(image_name)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = segment_hand(image)
    if image is None:
        print(f"Unable to segment image in {image_name}")
        return (None, None)
    inputs = processor(images=[image], return_tensors="pt").to(model.device)
    with torch.no_grad():
        embeddings = model.get_image_features(**inputs)
    collection.add(
        ids=[f"id{id}"],
        embeddings=embeddings.numpy()
    )
    return (embeddings.numpy(), cv2.resize(image, (64, 64)))


embeddings = []
images = []
image_names = []
for f in os.listdir("../../images/our-items/"):
    print(f"Embedding: {f}")
    (embedding, image) = embed_and_process_img(f"../../images/our-items/{f}", id, model, processor, collection)
    if embedding is not None and image is not None:
        embeddings.append(embedding)
        images.append(image)
        image_names.append(f.split(".")[0])
    id += 1

# %%
print(f"Embeddings: {len(embeddings)}, Images: {len(images)}, Image Names: {len(image_names)}")
images = np.array(images)

# %%
cosine_similarities = np.zeros((len(embeddings), len(embeddings)))

for i in range(len(embeddings)):
    for j in range(len(embeddings)):
        cosine_similarities[i, j] = cosine_similarity(embeddings[i].reshape(512), embeddings[j].reshape(512))

np.min(cosine_similarities)

# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

fig, ax = plt.subplots(figsize=(20, 20))
im = ax.imshow(cosine_similarities[:10, :10], vmin=0.6, vmax=1.0)

ax.set_xticks(range(10), labels=image_names[:10], rotation=45, ha="right", rotation_mode="anchor")
ax.set_yticks(range(10), labels=image_names[:10], rotation=45)

for y in range(10):
    imagebox = OffsetImage(images[y])
    ab = AnnotationBbox(
        imagebox,
        xy=(-0.1, -y / 10 + 0.95),
        xycoords='axes fraction',
        frameon=False
    )
    ax.add_artist(ab)

for x in range(10):
    imagebox = OffsetImage(images[x])
    ab = AnnotationBbox(
        imagebox,
        xy=(x / 10 + 0.05, -0.1),
        xycoords='axes fraction',
        frameon=False
    )
    ax.add_artist(ab)

for i in range(10):
    for j in range(10):
        text = ax.text(i, j, f"{round(cosine_similarities[i, j], 3)}", ha="center", va="center", color="w")

ax.set_title("Cosine Similarities")
fig.tight_layout()
plt.show()

# %%
for x in range(0, len(image_names), 10):
    for y in range(0, len(image_names), 10):
        fig, ax = plt.subplots(figsize=(20, 20))
        im = ax.imshow(cosine_similarities[y:(y+10), x:(x+10)], vmin=0.6, vmax=1.0)

        ax.set_xticks(range(len(image_names[x:(x+10)])), labels=image_names[x:(x+10)], rotation=45, ha="right", rotation_mode="anchor")
        ax.set_yticks(range(len(image_names[y:(y+10)])), labels=image_names[y:(y+10)], rotation=45)

        for i in range(len(image_names[y:(y+10)])):
            imagebox = OffsetImage(images[y + i])
            ab = AnnotationBbox(
                imagebox,
                xy=(-1 / len(image_names[x:(x+10)]), -i / len(image_names[y:(y+10)]) + 1 - 1 / (2 * len(image_names[y:(y+10)]))),
                xycoords='axes fraction',
                frameon=False
            )
            ax.add_artist(ab)

        for j in range(len(image_names[x:(x+10)])):
            imagebox = OffsetImage(images[x + j])
            ab = AnnotationBbox(
                imagebox,
                xy=(j / len(image_names[x:(x+10)]) + 1 / (2 * len(image_names[x:(x+10)])), -1 / len(image_names[y:(y+10)])),
                xycoords='axes fraction',
                frameon=False
            )
            ax.add_artist(ab)

        for i in range(len(image_names[x:(x+10)])):
            for j in range(len(image_names[y:(y+10)])):
                print(f"({x + i}, {y + j}): {cosine_similarities[x + i, y + j]}")
                text = ax.text(i, j, f"{round(cosine_similarities[x + i, y + j], 3)}", ha="center", va="center", color="w")
        
        ax.set_title(f"Cosine Similarities (x=[{x}, {x+10}]) (y=[{y}, {y+10}])")
        fig.tight_layout()
        plt.savefig(f"./heatmaps/cosine-similarities-{x}-{y}.png")
        plt.clf()
        plt.close()

# %%
closest_images = []
for i in range(len(image_names)):
    closest_image = np.argmax(cosine_similarities[i, [False if idx == i else True for idx in range(len(image_names))]])
    closest_images.append((image_names[i], image_names[closest_image], cosine_similarities[i, closest_image]))

# %%
closest_images

# %%
print(collection.count())
results = collection.query(query_embeddings=embeddings[0], n_results=10)
results

# %% [markdown]
# # TESTING THE DETECTION ALGORITHM

# %%
from transformers import AutoModel, AutoProcessor
import chromadb

model = AutoModel.from_pretrained(MODEL, device_map="auto").eval()
processor = AutoProcessor.from_pretrained(MODEL)
chroma_client = chromadb.Client()

try:
    chroma_client.delete_collection(name="detection_testing")
except:
    pass
collection = chroma_client.create_collection(
    name="detection_testing",
    configuration={
        "hnsw": {
            "space": "cosine"
        }
    },
    metadata={
        "description": "test dataset for embedding images so we can test our detection algorithm"
    }
)
id = 1

DETECT_THRESHOLD = 0.05

# %%
import torch
import cv2

def embed_image(image_name: str, id: int, picklist: str, model, processor, collection):
    image = cv2.imread(image_name)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = segment_hand(image)
    if image is None:
        print(f"Unable to segment image in {image_name}")
        return None
    inputs = processor(images=[image], return_tensors="pt").to(model.device)
    with torch.no_grad():
        embeddings = model.get_image_features(**inputs)
    collection.add(
        ids=[f"id{id}"],
        embeddings=embeddings.numpy(),
        metadatas=[{"picklist": picklist}]
    )
    return embeddings.numpy()

# %%
def perform_inference(embedding, collection):
    results = collection.query(query_embeddings=embedding)
    print(results)
    picklists = [results["metadatas"][0][i]["picklist"] for i in range(len(results["ids"][0])) if results["distances"][0][i] <= DETECT_THRESHOLD]
    bins = {}
    for picklist in picklists:
        for c in picklist:
            if c in bins:
                bins[c] += 1
            else:
                bins[c] = 1
    return (max(bins, key=bins.get), len(picklists))

# %%
import os
os.environ["GLOG_minloglevel"] = "3"   # 0=INFO, 1=WARNING, 2=ERROR
os.environ["absl_log_level"] = "3"

picklists = ["gbr", "b", "br"]

for (i, picklist) in enumerate(picklists):
    for f in os.listdir(f"../../images/picklist-test/{i}"):
        embedding = embed_image(
            f"../../images/picklist-test/{i}/{f}",
            id,
            picklist,
            model,
            processor,
            collection
        )
        id += 1
        (inference, total_results) = perform_inference(embedding, collection)
        print(f"Picklist: {picklist}, File: {f}, Inference: {inference}, Total Results: {total_results}")
